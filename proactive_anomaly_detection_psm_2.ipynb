# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
print(sys.executable)
# Out:
# /home/odbhutsc/anaconda3/envs/proactive_anomaly_detection/bin/python

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
import numpy as np
import os
import pandas as pd
import sys
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.distributions.normal import Normal

torch.cuda.empty_cache()

print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# 2.5.1
# True
# NVIDIA TITAN RTX
# cuda

# %%
# # csv_path = '/content/drive/MyDrive/rupa/archive/labeled_anomalies.csv'
# csv_path = r'C:\Users\skhandaker\OneDrive - Oklahoma City University\Documents\Anomaly Detection Paper\rupa\archive\labeled_anomalies.csv'

# df = pd.read_csv(csv_path)

# print(df["spacecraft"].unique())

# m_files = [f"{chan_id}.npy" for chan_id in df.loc[df['spacecraft']=='MSL', 'chan_id']]

# print(m_files)

# %%
# test_dir = '/content/drive/MyDrive/Research/anomaly_detection/RANSynCoders-main/data/test.csv'
# test_dir = r'C:\Users\skhandaker\OneDrive - Oklahoma City University\Documents\Anomaly Detection Paper\rupa\archive\data\data\test'
test_dir = "RANSynCoders-main/RANSynCoders-main/data/test.csv"

m_files = ["test.csv"]

df = pd.read_csv(test_dir)

X = df.values

print("Shape (rows, columns):", X.shape)
# Out:
# Shape (rows, columns): (87841, 26)

# %%
# test_dir = '/content/drive/MyDrive/Research/anomaly_detection/RANSynCoders-main/data'
# test_dir = r'C:\Users\skhandaker\OneDrive - Oklahoma City University\Documents\Anomaly Detection Paper\rupa\archive\data\data\test'
test_dir = "RANSynCoders-main/RANSynCoders-main/data"

data_list = []

for fname in m_files:
    file_path = os.path.join(test_dir, fname)
    df = pd.read_csv(file_path)
    arr = df.values
    chan_id = fname[:-4]
    chan_ids = np.full((arr.shape[0], 1), chan_id)
    row_numbers = np.arange(arr.shape[0]).reshape(-1, 1)
    combined = np.hstack([arr, chan_ids, row_numbers])

    data_list.append(combined)

X = np.vstack(data_list)

print(X)
# Out:
# [['132480.0' '0.7753739064836348' '0.9091851286139272' ...
#   '0.1059907834101382' 'test' '0']
#  ['132481.0' '0.7754228365977105' '0.9091417766193804' ...
#   '0.1105990783410138' 'test' '1']
#  ['132482.0' '0.7754575209491628' '0.9090036199283068' ...
#   '0.1152073732718894' 'test' '2']
#  ...
#  ['220318.0' '0.8646437313877637' '0.636236140496108' ...
#   '0.1290322580645161' 'test' '87838']
#  ['220319.0' '0.8645532389561273' '0.6434993402480025' ...
#   '0.0599078341013824' 'test' '87839']
#  ['220320.0' '0.8646953781925993' '0.6453373206525446' ...
#   '0.0506912442396313' 'test' '87840']]

# %%
print(X.shape)
# Out:
# (87841, 28)

# %%
# all_rows = []

# for f in m_files:
#     data = np.load(os.path.join(test_dir, f))
#     all_rows.append(data)

# combined = np.concatenate(all_rows, axis=0).astype(np.float32)


df = pd.DataFrame(X[:, :26], dtype=np.float32)
unique_embeddings = df.drop_duplicates()

print("Unique embeddings:", len(unique_embeddings))
print("Total time steps:", len(df))

print(type(df))
print(type(unique_embeddings))
# Out:
# Unique embeddings: 87841
# Total time steps: 87841
# <class 'pandas.DataFrame'>
# <class 'pandas.DataFrame'>

# %%
print(unique_embeddings)
# Out:
#              0         1         2         3         4         5         6   \
# 0      132480.0  0.775374  0.909185  0.606704  0.660626  0.449968  0.426717
# 1      132481.0  0.775423  0.909142  0.607796  0.660655  0.487813  0.442545
# 2      132482.0  0.775458  0.909004  0.607988  0.660623  0.469532  0.433682
# 3      132483.0  0.775513  0.909200  0.607218  0.660640  0.459910  0.435581
# 4      132484.0  0.775587  0.909318  0.606654  0.660643  0.462155  0.436214
# ...         ...       ...       ...       ...       ...       ...       ...
# 87836  220316.0  0.864548  0.660041  0.590923  0.413322  0.364657  0.380184
# 87837  220317.0  0.864483  0.536428  0.590742  0.413331  0.363695  0.378601
# 87838  220318.0  0.864644  0.636236  0.590451  0.413619  0.348942  0.377018
# 87839  220319.0  0.864553  0.643499  0.590222  0.413689  0.355997  0.379550
# 87840  220320.0  0.864695  0.645337  0.590731  0.413732  0.357280  0.371637
#
#              7         8         9   ...        16        17        18  \
# 0      0.471591  0.434668  0.479511  ...  0.400617  0.480444  0.588670
# 1      0.505682  0.448640  0.499451  ...  0.396902  0.500213  0.587041
# 2      0.477273  0.450906  0.487223  ...  0.389270  0.487982  0.582404
# 3      0.482955  0.454683  0.490431  ...  0.403780  0.491253  0.584660
# 4      0.477273  0.449396  0.494671  ...  0.403636  0.495947  0.581527
# ...         ...       ...       ...  ...       ...       ...       ...
# 87836  0.494318  0.450529  0.382934  ...  0.394973  0.386574  0.755608
# 87837  0.500000  0.451662  0.377564  ...  0.386467  0.381169  0.562101
# 87838  0.488636  0.438822  0.373536  ...  0.413731  0.377329  0.640556
# 87839  0.522727  0.448640  0.374963  ...  0.416956  0.378751  0.759744
# 87840  0.482955  0.440710  0.377801  ...  0.405995  0.381454  0.546685
#
#              19        20        21        22        23        24        25
# 0      0.404036  0.638957  0.020236  0.042705  0.173375  0.008715  0.105991
# 1      0.421605  0.637865  0.018550  0.042705  0.191826  0.010893  0.110599
# 2      0.407393  0.636091  0.018550  0.039146  0.188361  0.010893  0.115207
# 3      0.407141  0.638138  0.020236  0.042705  0.186975  0.013072  0.110599
# 4      0.402761  0.632678  0.021922  0.042705  0.156325  0.008715  0.110599
# ...         ...       ...       ...       ...       ...       ...       ...
# 87836  0.355207  0.835244  0.000000  0.028470  0.164872  0.021786  0.069124
# 87837  0.349141  0.490718  0.000000  0.010676  0.157812  0.015251  0.069124
# 87838  0.342261  0.700519  0.000000  0.028470  0.163298  0.015251  0.129032
# 87839  0.343052  0.828556  0.000000  0.032028  0.150160  0.017429  0.059908
# 87840  0.352665  0.617527  0.000000  0.003559  0.169520  0.013072  0.050691
#
# [87841 rows x 26 columns]

# %%
print(df)
# Out:
#              0         1         2         3         4         5         6   \
# 0      132480.0  0.775374  0.909185  0.606704  0.660626  0.449968  0.426717
# 1      132481.0  0.775423  0.909142  0.607796  0.660655  0.487813  0.442545
# 2      132482.0  0.775458  0.909004  0.607988  0.660623  0.469532  0.433682
# 3      132483.0  0.775513  0.909200  0.607218  0.660640  0.459910  0.435581
# 4      132484.0  0.775587  0.909318  0.606654  0.660643  0.462155  0.436214
# ...         ...       ...       ...       ...       ...       ...       ...
# 87836  220316.0  0.864548  0.660041  0.590923  0.413322  0.364657  0.380184
# 87837  220317.0  0.864483  0.536428  0.590742  0.413331  0.363695  0.378601
# 87838  220318.0  0.864644  0.636236  0.590451  0.413619  0.348942  0.377018
# 87839  220319.0  0.864553  0.643499  0.590222  0.413689  0.355997  0.379550
# 87840  220320.0  0.864695  0.645337  0.590731  0.413732  0.357280  0.371637
#
#              7         8         9   ...        16        17        18  \
# 0      0.471591  0.434668  0.479511  ...  0.400617  0.480444  0.588670
# 1      0.505682  0.448640  0.499451  ...  0.396902  0.500213  0.587041
# 2      0.477273  0.450906  0.487223  ...  0.389270  0.487982  0.582404
# 3      0.482955  0.454683  0.490431  ...  0.403780  0.491253  0.584660
# 4      0.477273  0.449396  0.494671  ...  0.403636  0.495947  0.581527
# ...         ...       ...       ...  ...       ...       ...       ...
# 87836  0.494318  0.450529  0.382934  ...  0.394973  0.386574  0.755608
# 87837  0.500000  0.451662  0.377564  ...  0.386467  0.381169  0.562101
# 87838  0.488636  0.438822  0.373536  ...  0.413731  0.377329  0.640556
# 87839  0.522727  0.448640  0.374963  ...  0.416956  0.378751  0.759744
# 87840  0.482955  0.440710  0.377801  ...  0.405995  0.381454  0.546685
#
#              19        20        21        22        23        24        25
# 0      0.404036  0.638957  0.020236  0.042705  0.173375  0.008715  0.105991
# 1      0.421605  0.637865  0.018550  0.042705  0.191826  0.010893  0.110599
# 2      0.407393  0.636091  0.018550  0.039146  0.188361  0.010893  0.115207
# 3      0.407141  0.638138  0.020236  0.042705  0.186975  0.013072  0.110599
# 4      0.402761  0.632678  0.021922  0.042705  0.156325  0.008715  0.110599
# ...         ...       ...       ...       ...       ...       ...       ...
# 87836  0.355207  0.835244  0.000000  0.028470  0.164872  0.021786  0.069124
# 87837  0.349141  0.490718  0.000000  0.010676  0.157812  0.015251  0.069124
# 87838  0.342261  0.700519  0.000000  0.028470  0.163298  0.015251  0.129032
# 87839  0.343052  0.828556  0.000000  0.032028  0.150160  0.017429  0.059908
# 87840  0.352665  0.617527  0.000000  0.003559  0.169520  0.013072  0.050691
#
# [87841 rows x 26 columns]

# %%
GPT_CONFIG = {
  "vocab_size": 87841, # Vocabulary size
  "context_length": 32, # Context length
  "emb_dim": 26, # Embedding dimension
  "n_heads": 2, # Number of attention heads
  "n_layers": 6, # Number of layers
  "drop_rate": 0.2, # Dropout rate
  "qkv_bias": False # Query-Key-Value bias
}

# %%
class MultiHeadAttention(nn.Module):
 def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
  super().__init__()
  assert (d_out % num_heads == 0), "d_out must be divisible by num_heads"
  self.d_out = d_out
  self.num_heads = num_heads
  self.head_dim = d_out // num_heads
  self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
  self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
  self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
  self.out_proj = nn.Linear(d_out, d_out)
  self.dropout = nn.Dropout(dropout)
  self.register_buffer("mask", torch.triu(torch.ones(context_length, context_length), diagonal=1))
 def forward(self, x):
  b, num_tokens, d_in = x.shape
  keys = self.W_key(x)
  queries = self.W_query(x)
  values = self.W_value(x)
  keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
  values = values.view(b, num_tokens, self.num_heads, self.head_dim)
  queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)
  keys = keys.transpose(1, 2)
  queries = queries.transpose(1, 2)
  values = values.transpose(1, 2)
  attn_scores = queries @ keys.transpose(2, 3)
  mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

  attn_scores.masked_fill_(mask_bool, -torch.inf)
  attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
  attn_weights = self.dropout(attn_weights)
  context_vec = (attn_weights @ values).transpose(1, 2)

  context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
  context_vec = self.out_proj(context_vec)
  return context_vec

# %%
class GELU(nn.Module):
  def __init__(self):
    super().__init__()

  def forward(self, x):
    return 0.5 * x * (1 + torch.tanh(torch.sqrt(torch.tensor(2.0 / torch.pi)) * (x + 0.044715 * torch.pow(x, 3))))

# %%
class FeedForward(nn.Module):
  def __init__(self, cfg):
    super().__init__()
    self.layers = nn.Sequential(nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), GELU(), nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]),)

  def forward(self, x):
    return self.layers(x)

# %%
class LayerNorm(nn.Module):
  def __init__(self, emb_dim):
    super().__init__()
    self.eps = 1e-5
    self.scale = nn.Parameter(torch.ones(emb_dim))
    self.shift = nn.Parameter(torch.zeros(emb_dim))
  def forward(self, x):
    mean = x.mean(dim=-1, keepdim=True)
    var = x.var(dim=-1, keepdim=True, unbiased=False)
    norm_x = (x - mean) / torch.sqrt(var + self.eps)
    return self.scale * norm_x + self.shift

# %%
class TransformerBlock(nn.Module):
  def __init__(self, cfg):
    super().__init__()
    self.att = MultiHeadAttention(d_in=cfg["emb_dim"], d_out=cfg["emb_dim"], context_length=cfg["context_length"], num_heads=cfg["n_heads"], dropout=cfg["drop_rate"], qkv_bias=cfg["qkv_bias"])
    self.ff = FeedForward(cfg)
    self.norm1 = LayerNorm(cfg["emb_dim"])
    self.norm2 = LayerNorm(cfg["emb_dim"])
    self.drop_shortcut = nn.Dropout(cfg["drop_rate"])
  def forward(self, x):
    shortcut = x
    x = self.norm1(x)
    x = self.att(x)
    x = self.drop_shortcut(x)
    x = x + shortcut
    shortcut = x
    x = self.norm2(x)
    x = self.ff(x)
    x = self.drop_shortcut(x)
    x = x + shortcut
    return x

# %%
c_unique_embeddings = unique_embeddings.values
emb_tuples = [tuple(row) for row in c_unique_embeddings]
print(len(emb_tuples))
emb2idx = {emb: idx for idx, emb in enumerate(emb_tuples)}
def get_embedding_ids(batch):
    batch_np = batch.detach().cpu().numpy().astype(np.float32)

    B, L, D = batch_np.shape
    ids = np.full((B, L), -1, dtype=int)

    for i in range(B):
        for j in range(L):
            ids[i, j] = emb2idx.get(tuple(batch_np[i, j]), -1)

    return ids
# Out:
# 87841

# %%
class GPTModel(nn.Module):
  def __init__(self, cfg):
    super().__init__()
    # self.cfg = cfg
    self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
    self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
    self.drop_emb = nn.Dropout(cfg["drop_rate"])

    self.trf_blocks = nn.Sequential(*[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

    self.final_norm = LayerNorm(cfg["emb_dim"])
    self.out_head = nn.Linear(cfg["emb_dim"], cfg["vocab_size"], bias=False)

  def forward(self, in_idx):
    global device
    batch_size, seq_len, _ = in_idx.shape
    in_idx = get_embedding_ids(in_idx)

    in_idx = torch.from_numpy(in_idx).long().to(device)

    tok_embeds = self.tok_emb(in_idx)
    pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
    x = tok_embeds + pos_embeds
    x = self.drop_emb(x)
    x = self.trf_blocks(x)
    x = self.final_norm(x)
    logits = self.out_head(x)
    return logits

# %%
train_ratio = 0.90
split_idx = int(train_ratio * len(X))
train_data = X[:split_idx]
val_data = X[split_idx:]

# %%
print(type(train_data))
print(type(val_data))
print(train_data)
print(val_data)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [['132480.0' '0.7753739064836348' '0.9091851286139272' ...
#   '0.1059907834101382' 'test' '0']
#  ['132481.0' '0.7754228365977105' '0.9091417766193804' ...
#   '0.1105990783410138' 'test' '1']
#  ['132482.0' '0.7754575209491628' '0.9090036199283068' ...
#   '0.1152073732718894' 'test' '2']
#  ...
#  ['211533.0' '0.7964793491824964' '0.7946117412252641' ...
#   '0.0921658986175115' 'test' '79053']
#  ['211534.0' '0.7962846988810984' '0.794414408949061' ...
#   '0.0829493087557603' 'test' '79054']
#  ['211535.0' '0.7963990709601704' '0.7943934229912035' ...
#   '0.0691244239631336' 'test' '79055']]
# [['211536.0' '0.7962013152170163' '0.7943621309437571' ...
#   '0.0783410138248848' 'test' '79056']
#  ['211537.0' '0.7961151965973118' '0.7942946680256983' ...
#   '0.0691244239631336' 'test' '79057']
#  ['211538.0' '0.7960242269961394' '0.7942100714447726' ...
#   '0.0967741935483871' 'test' '79058']
#  ...
#  ['220318.0' '0.8646437313877637' '0.636236140496108' ...
#   '0.1290322580645161' 'test' '87838']
#  ['220319.0' '0.8645532389561273' '0.6434993402480025' ...
#   '0.0599078341013824' 'test' '87839']
#  ['220320.0' '0.8646953781925993' '0.6453373206525446' ...
#   '0.0506912442396313' 'test' '87840']]

# %%
class GPTDatasetV1(Dataset):
  def __init__(self, txt, max_length, stride):
    self.input_ids = []
    self.target_ids = []

    # for txt in txts:
    for i in range(0, len(txt) - max_length, stride):
      input_chunk = txt[i:i + max_length]
      target_chunk = txt[i + 1: i + max_length + 1]
      self.input_ids.append(torch.tensor(input_chunk))
      self.target_ids.append(torch.tensor(target_chunk))
  def __len__(self):
    return len(self.input_ids)
  def __getitem__(self, idx):
    return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256, stride=128, shuffle=True, drop_last=True, num_workers=0):
  dataset = GPTDatasetV1(txt, max_length, stride)
  dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last, num_workers=num_workers)
  return dataloader

# %%
train_numeric = train_data[:, :26].astype(np.float32)
val_numeric = val_data[:, :26].astype(np.float32)

# Reduced batch size from 256 to 32 to prevent CUDA OOM
train_loader = create_dataloader_v1(
  train_numeric,
  batch_size=256,
  max_length=GPT_CONFIG["context_length"],
  stride=GPT_CONFIG["context_length"],
  drop_last=True,
  shuffle=True,
  num_workers=0
)

val_loader = create_dataloader_v1(
  val_numeric,
  batch_size=256,
  max_length=GPT_CONFIG["context_length"],
  stride=GPT_CONFIG["context_length"],
  drop_last=False,
  shuffle=False,
  num_workers=0
)

# %%
def calc_loss_batch(input_batch, target_emb_batch, model, device):
    input_batch = input_batch.to(device)
    target_emb_batch = target_emb_batch.to(device)
    logits = model(input_batch)
    target_ids = get_embedding_ids(target_emb_batch)
    target_ids = torch.from_numpy(target_ids).long().to(device)
    B, L, V = logits.size()
    logits_flat  = logits.view(B * L, V)
    targets_flat = target_ids.view(B * L)
    loss = torch.nn.functional.cross_entropy(logits_flat, targets_flat)
    return loss

# %%
def calc_loss_loader(data_loader, model, device, num_batches=None):
  total_loss = 0
  if len(data_loader) == 0:
    return float("nan")
  elif num_batches is None:
    num_batches = len(data_loader)
  else:
    num_batches = min(num_batches, len(data_loader))

  for i, (input_batch, target_batch) in enumerate(data_loader):
    if i < num_batches:
      loss = calc_loss_batch(input_batch, target_batch, model, device)
      total_loss += loss.item()
    else:
      break

  return total_loss / num_batches

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
  model.eval()
  with torch.no_grad():
    train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
    val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
  model.train()
  return train_loss, val_loss

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs, eval_freq, eval_iter):
  train_losses, val_losses, track_tokens_seen = [], [], []
  tokens_seen, global_step = 0, -1
  for epoch in range(num_epochs):
    model.train()
    for input_batch, target_batch in train_loader:
      optimizer.zero_grad()
      loss = calc_loss_batch(input_batch, target_batch, model, device)
      loss.backward()
      optimizer.step()
      tokens_seen += input_batch.numel()
      global_step += 1

      if global_step % eval_freq == 0:
        train_loss, val_loss = evaluate_model(model, train_loader, val_loader, device, eval_iter)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        track_tokens_seen.append(tokens_seen)
        print(f"Ep {epoch+1} (Step {global_step:06d}): Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")
  return train_losses, val_losses, track_tokens_seen

# %%
torch.manual_seed(42)
model = GPTModel(GPT_CONFIG)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = torch.optim.AdamW(
  model.parameters(),
  lr=0.0001, weight_decay=0.01
)
num_epochs = 200
train_losses, val_losses, tokens_seen = train_model_simple(
  model, train_loader, val_loader, optimizer, device,
  num_epochs=num_epochs, eval_freq=5, eval_iter=1
)
# Out:
# Ep 1 (Step 000000): Train loss 11.548, Val loss 11.554
# Ep 1 (Step 000005): Train loss 11.546, Val loss 11.555
# Ep 2 (Step 000010): Train loss 11.531, Val loss 11.557
# Ep 2 (Step 000015): Train loss 11.544, Val loss 11.560
# Ep 3 (Step 000020): Train loss 11.524, Val loss 11.563
# Ep 3 (Step 000025): Train loss 11.539, Val loss 11.566
# Ep 4 (Step 000030): Train loss 11.530, Val loss 11.568
# Ep 4 (Step 000035): Train loss 11.526, Val loss 11.571
# Ep 5 (Step 000040): Train loss 11.519, Val loss 11.574
# Ep 6 (Step 000045): Train loss 11.510, Val loss 11.577
# Ep 6 (Step 000050): Train loss 11.513, Val loss 11.580
# Ep 7 (Step 000055): Train loss 11.517, Val loss 11.583
# Ep 7 (Step 000060): Train loss 11.505, Val loss 11.586
# Ep 8 (Step 000065): Train loss 11.500, Val loss 11.589
# Ep 8 (Step 000070): Train loss 11.494, Val loss 11.592
# Ep 9 (Step 000075): Train loss 11.496, Val loss 11.595
# Ep 9 (Step 000080): Train loss 11.499, Val loss 11.599
# Ep 10 (Step 000085): Train loss 11.498, Val loss 11.602
# Ep 11 (Step 000090): Train loss 11.471, Val loss 11.606
# Ep 11 (Step 000095): Train loss 11.484, Val loss 11.609
# Ep 12 (Step 000100): Train loss 11.462, Val loss 11.613
# Ep 12 (Step 000105): Train loss 11.479, Val loss 11.617
# Ep 13 (Step 000110): Train loss 11.472, Val loss 11.621
# Ep 13 (Step 000115): Train loss 11.468, Val loss 11.625
# Ep 14 (Step 000120): Train loss 11.465, Val loss 11.629
# Ep 14 (Step 000125): Train loss 11.455, Val loss 11.633
# Ep 15 (Step 000130): Train loss 11.470, Val loss 11.637
# Ep 16 (Step 000135): Train loss 11.440, Val loss 11.641
# Ep 16 (Step 000140): Train loss 11.438, Val loss 11.646
# Ep 17 (Step 000145): Train loss 11.442, Val loss 11.650
# Ep 17 (Step 000150): Train loss 11.441, Val loss 11.655
# Ep 18 (Step 000155): Train loss 11.438, Val loss 11.660
# Ep 18 (Step 000160): Train loss 11.434, Val loss 11.664
# Ep 19 (Step 000165): Train loss 11.430, Val loss 11.669
# Ep 19 (Step 000170): Train loss 11.429, Val loss 11.674
# Ep 20 (Step 000175): Train loss 11.425, Val loss 11.679
# Ep 21 (Step 000180): Train loss 11.428, Val loss 11.684
# Ep 21 (Step 000185): Train loss 11.419, Val loss 11.689
# Ep 22 (Step 000190): Train loss 11.410, Val loss 11.694
# Ep 22 (Step 000195): Train loss 11.402, Val loss 11.699
# Ep 23 (Step 000200): Train loss 11.396, Val loss 11.704
# Ep 23 (Step 000205): Train loss 11.389, Val loss 11.709
# Ep 24 (Step 000210): Train loss 11.393, Val loss 11.715
# Ep 24 (Step 000215): Train loss 11.395, Val loss 11.719
# Ep 25 (Step 000220): Train loss 11.386, Val loss 11.724
# Ep 26 (Step 000225): Train loss 11.387, Val loss 11.728
# Ep 26 (Step 000230): Train loss 11.373, Val loss 11.733
# Ep 27 (Step 000235): Train loss 11.373, Val loss 11.738
# Ep 27 (Step 000240): Train loss 11.381, Val loss 11.743
# Ep 28 (Step 000245): Train loss 11.364, Val loss 11.747
# Ep 28 (Step 000250): Train loss 11.364, Val loss 11.752
# Ep 29 (Step 000255): Train loss 11.367, Val loss 11.756
# Ep 29 (Step 000260): Train loss 11.365, Val loss 11.761
# Ep 30 (Step 000265): Train loss 11.365, Val loss 11.765
# Ep 31 (Step 000270): Train loss 11.360, Val loss 11.769
# Ep 31 (Step 000275): Train loss 11.344, Val loss 11.774
# Ep 32 (Step 000280): Train loss 11.349, Val loss 11.778
# Ep 32 (Step 000285): Train loss 11.344, Val loss 11.781
# Ep 33 (Step 000290): Train loss 11.342, Val loss 11.785
# Ep 33 (Step 000295): Train loss 11.333, Val loss 11.790
# Ep 34 (Step 000300): Train loss 11.330, Val loss 11.793
# Ep 34 (Step 000305): Train loss 11.326, Val loss 11.797
# Ep 35 (Step 000310): Train loss 11.334, Val loss 11.801
# Ep 36 (Step 000315): Train loss 11.318, Val loss 11.804
# Ep 36 (Step 000320): Train loss 11.325, Val loss 11.807
# Ep 37 (Step 000325): Train loss 11.318, Val loss 11.811
# Ep 37 (Step 000330): Train loss 11.315, Val loss 11.814
# Ep 38 (Step 000335): Train loss 11.300, Val loss 11.818
# Ep 38 (Step 000340): Train loss 11.312, Val loss 11.821
# Ep 39 (Step 000345): Train loss 11.300, Val loss 11.825
# Ep 39 (Step 000350): Train loss 11.292, Val loss 11.828
# Ep 40 (Step 000355): Train loss 11.301, Val loss 11.832
# Ep 41 (Step 000360): Train loss 11.296, Val loss 11.836
# Ep 41 (Step 000365): Train loss 11.291, Val loss 11.839
# Ep 42 (Step 000370): Train loss 11.289, Val loss 11.842
# Ep 42 (Step 000375): Train loss 11.291, Val loss 11.845
# Ep 43 (Step 000380): Train loss 11.285, Val loss 11.848
# Ep 43 (Step 000385): Train loss 11.280, Val loss 11.850
# Ep 44 (Step 000390): Train loss 11.272, Val loss 11.854
# Ep 44 (Step 000395): Train loss 11.265, Val loss 11.856
# Ep 45 (Step 000400): Train loss 11.269, Val loss 11.859
# Ep 46 (Step 000405): Train loss 11.266, Val loss 11.860
# Ep 46 (Step 000410): Train loss 11.253, Val loss 11.862
# Ep 47 (Step 000415): Train loss 11.263, Val loss 11.865
# Ep 47 (Step 000420): Train loss 11.256, Val loss 11.867
# Ep 48 (Step 000425): Train loss 11.251, Val loss 11.869
# Ep 48 (Step 000430): Train loss 11.250, Val loss 11.872
# Ep 49 (Step 000435): Train loss 11.247, Val loss 11.874
# Ep 49 (Step 000440): Train loss 11.237, Val loss 11.876
# Ep 50 (Step 000445): Train loss 11.242, Val loss 11.878
# Ep 51 (Step 000450): Train loss 11.232, Val loss 11.880
# Ep 51 (Step 000455): Train loss 11.234, Val loss 11.882
# Ep 52 (Step 000460): Train loss 11.227, Val loss 11.884
# Ep 52 (Step 000465): Train loss 11.227, Val loss 11.887
# Ep 53 (Step 000470): Train loss 11.229, Val loss 11.889
# Ep 53 (Step 000475): Train loss 11.222, Val loss 11.892
# Ep 54 (Step 000480): Train loss 11.202, Val loss 11.894
# Ep 54 (Step 000485): Train loss 11.232, Val loss 11.896
# Ep 55 (Step 000490): Train loss 11.212, Val loss 11.898
# Ep 56 (Step 000495): Train loss 11.204, Val loss 11.899
# Ep 56 (Step 000500): Train loss 11.200, Val loss 11.901
# Ep 57 (Step 000505): Train loss 11.200, Val loss 11.903
# Ep 57 (Step 000510): Train loss 11.192, Val loss 11.905
# Ep 58 (Step 000515): Train loss 11.191, Val loss 11.905
# Ep 58 (Step 000520): Train loss 11.189, Val loss 11.907
# Ep 59 (Step 000525): Train loss 11.194, Val loss 11.908
# Ep 59 (Step 000530): Train loss 11.185, Val loss 11.909
# Ep 60 (Step 000535): Train loss 11.175, Val loss 11.911
# Ep 61 (Step 000540): Train loss 11.183, Val loss 11.912
# Ep 61 (Step 000545): Train loss 11.169, Val loss 11.913
# Ep 62 (Step 000550): Train loss 11.168, Val loss 11.915
# Ep 62 (Step 000555): Train loss 11.169, Val loss 11.915
# Ep 63 (Step 000560): Train loss 11.171, Val loss 11.918
# Ep 63 (Step 000565): Train loss 11.160, Val loss 11.920
# Ep 64 (Step 000570): Train loss 11.158, Val loss 11.921
# Ep 64 (Step 000575): Train loss 11.156, Val loss 11.922
# Ep 65 (Step 000580): Train loss 11.155, Val loss 11.924
# Ep 66 (Step 000585): Train loss 11.151, Val loss 11.926
# Ep 66 (Step 000590): Train loss 11.145, Val loss 11.927
# Ep 67 (Step 000595): Train loss 11.149, Val loss 11.929
# Ep 67 (Step 000600): Train loss 11.147, Val loss 11.931
# Ep 68 (Step 000605): Train loss 11.142, Val loss 11.930
# Ep 68 (Step 000610): Train loss 11.132, Val loss 11.930
# Ep 69 (Step 000615): Train loss 11.131, Val loss 11.931
# Ep 69 (Step 000620): Train loss 11.126, Val loss 11.933
# Ep 70 (Step 000625): Train loss 11.122, Val loss 11.936
# Ep 71 (Step 000630): Train loss 11.123, Val loss 11.939
# Ep 71 (Step 000635): Train loss 11.116, Val loss 11.941
# Ep 72 (Step 000640): Train loss 11.116, Val loss 11.943
# Ep 72 (Step 000645): Train loss 11.108, Val loss 11.945
# Ep 73 (Step 000650): Train loss 11.107, Val loss 11.946
# Ep 73 (Step 000655): Train loss 11.103, Val loss 11.946
# Ep 74 (Step 000660): Train loss 11.095, Val loss 11.946
# Ep 74 (Step 000665): Train loss 11.097, Val loss 11.947
# Ep 75 (Step 000670): Train loss 11.097, Val loss 11.948
# Ep 76 (Step 000675): Train loss 11.092, Val loss 11.948
# Ep 76 (Step 000680): Train loss 11.090, Val loss 11.949
# Ep 77 (Step 000685): Train loss 11.078, Val loss 11.950
# Ep 77 (Step 000690): Train loss 11.084, Val loss 11.953
# Ep 78 (Step 000695): Train loss 11.074, Val loss 11.955
# Ep 78 (Step 000700): Train loss 11.072, Val loss 11.956
# Ep 79 (Step 000705): Train loss 11.072, Val loss 11.957
# Ep 79 (Step 000710): Train loss 11.065, Val loss 11.959
# Ep 80 (Step 000715): Train loss 11.076, Val loss 11.960
# Ep 81 (Step 000720): Train loss 11.057, Val loss 11.962
# Ep 81 (Step 000725): Train loss 11.049, Val loss 11.963
# Ep 82 (Step 000730): Train loss 11.052, Val loss 11.964
# Ep 82 (Step 000735): Train loss 11.045, Val loss 11.965
# Ep 83 (Step 000740): Train loss 11.054, Val loss 11.967
# Ep 83 (Step 000745): Train loss 11.044, Val loss 11.969
# Ep 84 (Step 000750): Train loss 11.043, Val loss 11.969
# Ep 84 (Step 000755): Train loss 11.041, Val loss 11.969
# Ep 85 (Step 000760): Train loss 11.034, Val loss 11.970
# Ep 86 (Step 000765): Train loss 11.025, Val loss 11.972
# Ep 86 (Step 000770): Train loss 11.029, Val loss 11.975
# Ep 87 (Step 000775): Train loss 11.032, Val loss 11.976
# Ep 87 (Step 000780): Train loss 11.014, Val loss 11.978
# Ep 88 (Step 000785): Train loss 11.011, Val loss 11.979
# Ep 88 (Step 000790): Train loss 11.012, Val loss 11.980
# Ep 89 (Step 000795): Train loss 11.015, Val loss 11.982
# Ep 89 (Step 000800): Train loss 11.008, Val loss 11.983
# Ep 90 (Step 000805): Train loss 11.005, Val loss 11.984
# Ep 91 (Step 000810): Train loss 11.002, Val loss 11.986
# Ep 91 (Step 000815): Train loss 11.010, Val loss 11.988
# Ep 92 (Step 000820): Train loss 10.999, Val loss 11.988
# Ep 92 (Step 000825): Train loss 10.989, Val loss 11.988
# Ep 93 (Step 000830): Train loss 10.987, Val loss 11.989
# Ep 93 (Step 000835): Train loss 10.981, Val loss 11.990
# Ep 94 (Step 000840): Train loss 10.972, Val loss 11.991
# Ep 94 (Step 000845): Train loss 10.980, Val loss 11.992
# Ep 95 (Step 000850): Train loss 10.965, Val loss 11.993
# Ep 96 (Step 000855): Train loss 10.955, Val loss 11.995
# Ep 96 (Step 000860): Train loss 10.967, Val loss 11.996
# Ep 97 (Step 000865): Train loss 10.970, Val loss 11.999
# Ep 97 (Step 000870): Train loss 10.954, Val loss 12.001
# Ep 98 (Step 000875): Train loss 10.958, Val loss 12.002
# Ep 98 (Step 000880): Train loss 10.950, Val loss 12.003
# Ep 99 (Step 000885): Train loss 10.959, Val loss 12.005
# Ep 99 (Step 000890): Train loss 10.940, Val loss 12.007
# Ep 100 (Step 000895): Train loss 10.932, Val loss 12.009
# Ep 101 (Step 000900): Train loss 10.939, Val loss 12.010
# Ep 101 (Step 000905): Train loss 10.935, Val loss 12.011
# Ep 102 (Step 000910): Train loss 10.939, Val loss 12.012
# Ep 102 (Step 000915): Train loss 10.926, Val loss 12.013
# Ep 103 (Step 000920): Train loss 10.929, Val loss 12.014
# Ep 103 (Step 000925): Train loss 10.922, Val loss 12.015
# Ep 104 (Step 000930): Train loss 10.935, Val loss 12.017
# Ep 104 (Step 000935): Train loss 10.912, Val loss 12.019
# Ep 105 (Step 000940): Train loss 10.907, Val loss 12.021
# Ep 106 (Step 000945): Train loss 10.901, Val loss 12.022
# Ep 106 (Step 000950): Train loss 10.897, Val loss 12.023
# Ep 107 (Step 000955): Train loss 10.902, Val loss 12.025
# Ep 107 (Step 000960): Train loss 10.893, Val loss 12.027
# Ep 108 (Step 000965): Train loss 10.905, Val loss 12.030
# Ep 108 (Step 000970): Train loss 10.884, Val loss 12.032
# Ep 109 (Step 000975): Train loss 10.892, Val loss 12.034
# Ep 109 (Step 000980): Train loss 10.881, Val loss 12.035
# Ep 110 (Step 000985): Train loss 10.878, Val loss 12.037
# Ep 111 (Step 000990): Train loss 10.872, Val loss 12.038
# Ep 111 (Step 000995): Train loss 10.855, Val loss 12.039
# Ep 112 (Step 001000): Train loss 10.870, Val loss 12.040
# Ep 112 (Step 001005): Train loss 10.866, Val loss 12.041
# Ep 113 (Step 001010): Train loss 10.858, Val loss 12.043
# Ep 113 (Step 001015): Train loss 10.849, Val loss 12.046
# Ep 114 (Step 001020): Train loss 10.866, Val loss 12.048
# Ep 114 (Step 001025): Train loss 10.847, Val loss 12.049
# Ep 115 (Step 001030): Train loss 10.846, Val loss 12.050
# Ep 116 (Step 001035): Train loss 10.844, Val loss 12.052
# Ep 116 (Step 001040): Train loss 10.829, Val loss 12.053
# Ep 117 (Step 001045): Train loss 10.838, Val loss 12.055
# Ep 117 (Step 001050): Train loss 10.838, Val loss 12.057
# Ep 118 (Step 001055): Train loss 10.831, Val loss 12.058
# Ep 118 (Step 001060): Train loss 10.820, Val loss 12.059
# Ep 119 (Step 001065): Train loss 10.820, Val loss 12.060
# Ep 119 (Step 001070): Train loss 10.812, Val loss 12.061
# Ep 120 (Step 001075): Train loss 10.813, Val loss 12.063
# Ep 121 (Step 001080): Train loss 10.815, Val loss 12.066
# Ep 121 (Step 001085): Train loss 10.792, Val loss 12.068
# Ep 122 (Step 001090): Train loss 10.808, Val loss 12.070
# Ep 122 (Step 001095): Train loss 10.793, Val loss 12.073
# Ep 123 (Step 001100): Train loss 10.803, Val loss 12.074
# Ep 123 (Step 001105): Train loss 10.793, Val loss 12.076
# Ep 124 (Step 001110): Train loss 10.792, Val loss 12.077
# Ep 124 (Step 001115): Train loss 10.785, Val loss 12.078
# Ep 125 (Step 001120): Train loss 10.774, Val loss 12.081
# Ep 126 (Step 001125): Train loss 10.775, Val loss 12.083
# Ep 126 (Step 001130): Train loss 10.775, Val loss 12.084
# Ep 127 (Step 001135): Train loss 10.767, Val loss 12.085
# Ep 127 (Step 001140): Train loss 10.762, Val loss 12.088
# Ep 128 (Step 001145): Train loss 10.768, Val loss 12.091
# Ep 128 (Step 001150): Train loss 10.760, Val loss 12.093
# Ep 129 (Step 001155): Train loss 10.751, Val loss 12.092
# Ep 129 (Step 001160): Train loss 10.746, Val loss 12.094
# Ep 130 (Step 001165): Train loss 10.750, Val loss 12.096
# Ep 131 (Step 001170): Train loss 10.750, Val loss 12.098
# Ep 131 (Step 001175): Train loss 10.738, Val loss 12.100
# Ep 132 (Step 001180): Train loss 10.728, Val loss 12.101
# Ep 132 (Step 001185): Train loss 10.739, Val loss 12.102
# Ep 133 (Step 001190): Train loss 10.719, Val loss 12.104
# Ep 133 (Step 001195): Train loss 10.715, Val loss 12.106
# Ep 134 (Step 001200): Train loss 10.718, Val loss 12.108
# Ep 134 (Step 001205): Train loss 10.716, Val loss 12.110
# Ep 135 (Step 001210): Train loss 10.705, Val loss 12.111
# Ep 136 (Step 001215): Train loss 10.709, Val loss 12.114
# Ep 136 (Step 001220): Train loss 10.700, Val loss 12.116
# Ep 137 (Step 001225): Train loss 10.698, Val loss 12.118
# Ep 137 (Step 001230): Train loss 10.692, Val loss 12.119
# Ep 138 (Step 001235): Train loss 10.690, Val loss 12.120
# Ep 138 (Step 001240): Train loss 10.690, Val loss 12.120
# Ep 139 (Step 001245): Train loss 10.685, Val loss 12.123
# Ep 139 (Step 001250): Train loss 10.690, Val loss 12.126
# Ep 140 (Step 001255): Train loss 10.676, Val loss 12.129
# Ep 141 (Step 001260): Train loss 10.678, Val loss 12.131
# Ep 141 (Step 001265): Train loss 10.675, Val loss 12.134
# Ep 142 (Step 001270): Train loss 10.662, Val loss 12.135
# Ep 142 (Step 001275): Train loss 10.657, Val loss 12.137
# Ep 143 (Step 001280): Train loss 10.667, Val loss 12.140
# Ep 143 (Step 001285): Train loss 10.652, Val loss 12.142
# Ep 144 (Step 001290): Train loss 10.643, Val loss 12.145
# Ep 144 (Step 001295): Train loss 10.646, Val loss 12.147
# Ep 145 (Step 001300): Train loss 10.633, Val loss 12.148
# Ep 146 (Step 001305): Train loss 10.631, Val loss 12.149
# Ep 146 (Step 001310): Train loss 10.628, Val loss 12.150
# Ep 147 (Step 001315): Train loss 10.620, Val loss 12.151
# Ep 147 (Step 001320): Train loss 10.618, Val loss 12.154
# Ep 148 (Step 001325): Train loss 10.625, Val loss 12.156
# Ep 148 (Step 001330): Train loss 10.622, Val loss 12.158
# Ep 149 (Step 001335): Train loss 10.615, Val loss 12.159
# Ep 149 (Step 001340): Train loss 10.605, Val loss 12.161
# Ep 150 (Step 001345): Train loss 10.599, Val loss 12.163
# Ep 151 (Step 001350): Train loss 10.592, Val loss 12.165
# Ep 151 (Step 001355): Train loss 10.594, Val loss 12.167
# Ep 152 (Step 001360): Train loss 10.596, Val loss 12.170
# Ep 152 (Step 001365): Train loss 10.586, Val loss 12.173
# Ep 153 (Step 001370): Train loss 10.592, Val loss 12.174
# Ep 153 (Step 001375): Train loss 10.583, Val loss 12.174
# Ep 154 (Step 001380): Train loss 10.577, Val loss 12.176
# Ep 154 (Step 001385): Train loss 10.573, Val loss 12.177
# Ep 155 (Step 001390): Train loss 10.570, Val loss 12.179
# Ep 156 (Step 001395): Train loss 10.565, Val loss 12.182
# Ep 156 (Step 001400): Train loss 10.563, Val loss 12.185
# Ep 157 (Step 001405): Train loss 10.559, Val loss 12.188
# Ep 157 (Step 001410): Train loss 10.543, Val loss 12.191
# Ep 158 (Step 001415): Train loss 10.548, Val loss 12.193
# Ep 158 (Step 001420): Train loss 10.540, Val loss 12.195
# Ep 159 (Step 001425): Train loss 10.549, Val loss 12.196
# Ep 159 (Step 001430): Train loss 10.525, Val loss 12.197
# Ep 160 (Step 001435): Train loss 10.522, Val loss 12.200
# Ep 161 (Step 001440): Train loss 10.520, Val loss 12.202
# Ep 161 (Step 001445): Train loss 10.528, Val loss 12.204
# Ep 162 (Step 001450): Train loss 10.511, Val loss 12.206
# Ep 162 (Step 001455): Train loss 10.526, Val loss 12.208
# Ep 163 (Step 001460): Train loss 10.506, Val loss 12.209
# Ep 163 (Step 001465): Train loss 10.513, Val loss 12.211
# Ep 164 (Step 001470): Train loss 10.518, Val loss 12.212
# Ep 164 (Step 001475): Train loss 10.496, Val loss 12.213
# Ep 165 (Step 001480): Train loss 10.510, Val loss 12.216
# Ep 166 (Step 001485): Train loss 10.492, Val loss 12.219
# Ep 166 (Step 001490): Train loss 10.487, Val loss 12.221
# Ep 167 (Step 001495): Train loss 10.472, Val loss 12.224
# Ep 167 (Step 001500): Train loss 10.472, Val loss 12.227
# Ep 168 (Step 001505): Train loss 10.472, Val loss 12.230
# Ep 168 (Step 001510): Train loss 10.467, Val loss 12.233
# Ep 169 (Step 001515): Train loss 10.470, Val loss 12.236
# Ep 169 (Step 001520): Train loss 10.466, Val loss 12.236
# Ep 170 (Step 001525): Train loss 10.462, Val loss 12.236
# Ep 171 (Step 001530): Train loss 10.445, Val loss 12.238
# Ep 171 (Step 001535): Train loss 10.452, Val loss 12.239
# Ep 172 (Step 001540): Train loss 10.447, Val loss 12.241
# Ep 172 (Step 001545): Train loss 10.442, Val loss 12.244
# Ep 173 (Step 001550): Train loss 10.441, Val loss 12.247
# Ep 173 (Step 001555): Train loss 10.433, Val loss 12.250
# Ep 174 (Step 001560): Train loss 10.431, Val loss 12.253
# Ep 174 (Step 001565): Train loss 10.420, Val loss 12.256
# Ep 175 (Step 001570): Train loss 10.422, Val loss 12.258
# Ep 176 (Step 001575): Train loss 10.415, Val loss 12.261
# Ep 176 (Step 001580): Train loss 10.400, Val loss 12.262
# Ep 177 (Step 001585): Train loss 10.410, Val loss 12.265
# Ep 177 (Step 001590): Train loss 10.413, Val loss 12.267
# Ep 178 (Step 001595): Train loss 10.398, Val loss 12.270
# Ep 178 (Step 001600): Train loss 10.393, Val loss 12.272
# Ep 179 (Step 001605): Train loss 10.397, Val loss 12.272
# Ep 179 (Step 001610): Train loss 10.393, Val loss 12.272
# Ep 180 (Step 001615): Train loss 10.379, Val loss 12.274
# Ep 181 (Step 001620): Train loss 10.379, Val loss 12.277
# Ep 181 (Step 001625): Train loss 10.375, Val loss 12.281
# Ep 182 (Step 001630): Train loss 10.375, Val loss 12.284
# Ep 182 (Step 001635): Train loss 10.379, Val loss 12.287
# Ep 183 (Step 001640): Train loss 10.360, Val loss 12.289
# Ep 183 (Step 001645): Train loss 10.360, Val loss 12.291
# Ep 184 (Step 001650): Train loss 10.358, Val loss 12.293
# Ep 184 (Step 001655): Train loss 10.348, Val loss 12.295
# Ep 185 (Step 001660): Train loss 10.355, Val loss 12.297
# Ep 186 (Step 001665): Train loss 10.342, Val loss 12.300
# Ep 186 (Step 001670): Train loss 10.341, Val loss 12.301
# Ep 187 (Step 001675): Train loss 10.322, Val loss 12.303
# Ep 187 (Step 001680): Train loss 10.338, Val loss 12.305
# Ep 188 (Step 001685): Train loss 10.328, Val loss 12.307
# Ep 188 (Step 001690): Train loss 10.318, Val loss 12.309
# Ep 189 (Step 001695): Train loss 10.316, Val loss 12.313
# Ep 189 (Step 001700): Train loss 10.312, Val loss 12.315
# Ep 190 (Step 001705): Train loss 10.305, Val loss 12.316
# Ep 191 (Step 001710): Train loss 10.301, Val loss 12.318
# Ep 191 (Step 001715): Train loss 10.288, Val loss 12.322
# Ep 192 (Step 001720): Train loss 10.287, Val loss 12.325
# Ep 192 (Step 001725): Train loss 10.301, Val loss 12.329
# Ep 193 (Step 001730): Train loss 10.281, Val loss 12.330
# Ep 193 (Step 001735): Train loss 10.289, Val loss 12.332
# Ep 194 (Step 001740): Train loss 10.280, Val loss 12.335
# Ep 194 (Step 001745): Train loss 10.275, Val loss 12.336
# Ep 195 (Step 001750): Train loss 10.273, Val loss 12.339
# Ep 196 (Step 001755): Train loss 10.270, Val loss 12.341
# Ep 196 (Step 001760): Train loss 10.255, Val loss 12.343
# Ep 197 (Step 001765): Train loss 10.258, Val loss 12.345
# Ep 197 (Step 001770): Train loss 10.253, Val loss 12.348
# Ep 198 (Step 001775): Train loss 10.245, Val loss 12.349
# Ep 198 (Step 001780): Train loss 10.236, Val loss 12.351
# Ep 199 (Step 001785): Train loss 10.235, Val loss 12.353
# Ep 199 (Step 001790): Train loss 10.236, Val loss 12.356
# Ep 200 (Step 001795): Train loss 10.241, Val loss 12.360

# %%
# import ast
# csv_path = 'C:\Users\skhandaker\Documents\RANSynCoders-main\RANSynCoders-main\data\test_label.csv'
# df = pd.read_csv(csv_path)

# anomaly_masks = {}

# for index, row in df.iterrows():
#     print(index)
#     print(row)
#     chan = row["chan_id"]
#     num_values = row["num_values"]
#     intervals = ast.literalA_eval(row["anomaly_sequences"])

#     mask = np.zeros(num_values, dtype=bool)

#     for start, end in intervals:
#         mask[start:end+1] = True

#     anomaly_masks[chan] = mask

# %%
# label_filename = r'C:\Users\skhandaker\Documents\RANSynCoders-main\RANSynCoders-main\data\test_label.csv'
# # label_filename = r'C:\Users\skhandaker\OneDrive - Oklahoma City University\Documents\Anomaly Detection Paper\rupa\archive\labeled_anomalies.csv'
# labels_df = pd.read_csv(label_filename)

# test_labels = labels_df.iloc[:, 1].values.astype(bool)

# if 'anomaly_masks' not in locals():
#     anomaly_masks = {}

# anomaly_masks['test'] = test_labels

# %%
import pandas as pd
import numpy as np

csv_path = 'RANSynCoders-main/RANSynCoders-main/data/test_label.csv'
df = pd.read_csv(csv_path)

# Directly extract label column
test_labels = df["label"].values.astype(bool)

# Store in anomaly_masks dictionary
anomaly_masks = {}
anomaly_masks["test"] = test_labels

# %%
context = GPT_CONFIG["context_length"]
forecast_horizon = context

model.eval()
dists, uncertainties, expecteds, y_targets = [], [], [], []

with torch.no_grad():
    for t in range(len(val_data) - context - forecast_horizon):
    # for t in range(5):
        init_seq = val_data[t : t+context, :26].astype(np.float32)
        init_seq = init_seq[np.newaxis]
        init_seq = torch.tensor(init_seq, device=device)
        true_seq = val_data[t+context : t+context+forecast_horizon, :26].astype(np.float32)

        # print(pred_emb)
        predicted_embs = []
        for _ in range(forecast_horizon):
            logits = model(init_seq)
            next_id = logits[0, -1].argmax().item()
            # print(next_id)
            pred_emb = emb_tuples[next_id]
            # print(pred_emb)
            predicted_embs.append(pred_emb)

            next_emb = torch.tensor(pred_emb, device=device)
            next_emb = next_emb.unsqueeze(0).unsqueeze(0)
            init_seq = torch.cat([init_seq, next_emb], dim=1)[:, -context:, :]
        dist = np.linalg.norm(predicted_embs - true_seq)

        # chan_id = val_data[t, 26]
        row_indices = val_data[t+context : t+context+forecast_horizon, 27].astype(int)
        mask = anomaly_masks["test"]
        window_is_anomaly = mask[row_indices].any()

        # print(dist)
        # print(window_is_a 
        dists.append(dist)
        y_targets.append(window_is_anomaly)

const = np.sqrt(2.0 / np.pi)

for m in model.modules():
    if isinstance(m, nn.Dropout):
        m.train()

with torch.no_grad():
    for t in range(len(val_data) - context - forecast_horizon):
    # for t in range(5):
        init_seq = val_data[t : t+context, :26].astype(np.float32)
        init_seq = init_seq[np.newaxis]
        init_seq = torch.tensor(init_seq, device=device)
        true_seq = val_data[t+context : t+context+forecast_horizon, :26].astype(np.float32)

        # print(pred_emb)
        predicted_embs = []
        for _ in range(forecast_horizon):
        # for _ in range(2):
            logits = model(init_seq)
            next_id = logits[0, -1].argmax().item()
            pred_emb = torch.tensor(emb_tuples[next_id], device=device, dtype=torch.float32)
            # print(len(pred_emb))
            predicted_embs.append(pred_emb)
        # print(predicted_embs)
        predicted_embs = torch.vstack(predicted_embs)
        uncertainty = predicted_embs.std(0).norm()
        uncertainties.append(uncertainty)
        expecteds.append(const * uncertainty)
        # break

# %%
# dists should be Python floats – move them to same device
d_tensor = torch.tensor(dists, device=device, dtype=torch.float32)

# uncertainties and expecteds are lists of CUDA tensors → stack them
u_tensor = torch.tensor(uncertainties, device=device, dtype=torch.float32)
e_tensor = torch.tensor(expecteds, device=device, dtype=torch.float32)

d_norm = (d_tensor - d_tensor.min()) / (d_tensor.max() - d_tensor.min())
u_norm = (u_tensor - u_tensor.min()) / (u_tensor.max() - u_tensor.min())
e_norm = (e_tensor - e_tensor.min()) / (e_tensor.max() - e_tensor.min())

# y_preds = d_norm + u_norm + e_norm
# st = d_norm + u_norm + e_norm
# z_t = s_t / (3 ** 0.5)
# normal = Normal(0, 1)
# p_t = 1 - normal.cdf(z_t)
# y_preds = (y_preds > p_t).to(torch.int)
# y_preds = y_preds.detach().cpu().numpy()
# print(y_preds)

# %%
s_t = d_norm + u_norm + e_norm

mu = s_t.mean()
sigma = s_t.std()

z_t = (s_t - mu) / sigma

print(z_t.min(), z_t.max())

# y_preds = (z_t > 1.5).to(torch.int)
threshold = torch.quantile(z_t, 0.60)
y_preds = (z_t > threshold).to(torch.int)
print(y_preds)
# Out:
# tensor(-4.9438, device='cuda:0') tensor(2.5803, device='cuda:0')
# tensor([0, 0, 1,  ..., 0, 0, 0], device='cuda:0', dtype=torch.int32)

# %%
from sklearn import metrics
import copy

##### Evaluation Metrics #####

def pak(preds, targets, k=20):

    predicts = preds
    actuals = targets

    one_start_idx = np.where(np.diff(actuals, prepend=0) == 1)[0]
    zero_start_idx = np.where(np.diff(actuals, prepend=0) == -1)[0]

    assert len(one_start_idx) == len(zero_start_idx) + 1 or len(one_start_idx) == len(zero_start_idx)

    if len(one_start_idx) == len(zero_start_idx) + 1:
        zero_start_idx = np.append(zero_start_idx, len(predicts))

    for i in range(len(one_start_idx)):
        if predicts[one_start_idx[i]:zero_start_idx[i]].sum() > k / 100 * (zero_start_idx[i] - one_start_idx[i]):
            predicts[one_start_idx[i]:zero_start_idx[i]] = 1

    return predicts

def get_events(y_test, outlier=1, normal=0):
    events = dict()
    label_prev = normal
    event = 0
    event_start = 0
    for tim, label in enumerate(y_test):
        if label == outlier:
            if label_prev == normal:
                event += 1
                event_start = tim
        else:
            if label_prev == outlier:
                event_end = tim - 1
                events[event] = (event_start, event_end)
        label_prev = label

    if label_prev == outlier:
        event_end = tim - 1
        events[event] = (event_start, event_end)
    return events

def get_composite_fscore_raw(pred_labels, true_events, y_test, return_prec_rec=False):
    epsilon = 1e-8
    tp = np.sum([pred_labels[start:end + 1].any() for start, end in true_events.values()])
    fn = len(true_events) - tp
    rec_e = tp/(tp + fn)
    prec_t = metrics.precision_score(y_test, pred_labels, zero_division=0)
    fscore_c = 2 * rec_e * prec_t / (rec_e + prec_t + epsilon)
    if prec_t == 0 and rec_e == 0:
        fscore_c = 0
    if return_prec_rec:
        return prec_t, rec_e, fscore_c
    return fscore_c

def constant_bias_fn(inputs):

    return np.sum(inputs) / inputs.shape[0]

def improved_cardinality_fn(cardinality, gt_length):

    return ((gt_length - 1) / gt_length) ** (cardinality - 1)

def compute_window_indices(binary_labels):

    boundaries = np.empty_like(binary_labels)
    boundaries[0] = 0
    boundaries[1:] = binary_labels[:-1]
    boundaries *= -1
    boundaries += binary_labels

    indices = np.nonzero(boundaries)[0].tolist()
    if len(indices) % 2 != 0:
        indices.append(binary_labels.shape[0])
    indices = [(indices[i], indices[i + 1]) for i in range(0, len(indices), 2)]

    return indices

def _compute_overlap(preds, pred_indices, gt_indices, alpha, bias_fn, cardinality_fn, use_window_weight = False):
    n_gt_windows = len(gt_indices)
    n_pred_windows = len(pred_indices)
    total_score = 0.0
    total_gt_points = 0

    i = j = 0
    while i < n_gt_windows and j < n_pred_windows:
        gt_start, gt_end = gt_indices[i]
        window_length = gt_end - gt_start
        total_gt_points += window_length
        i += 1

        cardinality = 0
        while j < n_pred_windows and pred_indices[j][1] <= gt_start:
            j += 1
        while j < n_pred_windows and pred_indices[j][0] < gt_end:
            j += 1
            cardinality += 1

        if cardinality == 0:
            continue

        j -= 1

        cardinality_multiplier = cardinality_fn(cardinality, window_length)

        prediction_inside_ground_truth = preds[gt_start:gt_end]
        omega = bias_fn(prediction_inside_ground_truth)

        weight = window_length if use_window_weight else 1

        total_score += alpha * weight
        total_score += (1 - alpha) * cardinality_multiplier * omega * weight

    denom = total_gt_points if use_window_weight else n_gt_windows

    return total_score / denom

def ts_precision_and_recall(anomalies, predictions, alpha = 0,
                            recall_bias_fn = constant_bias_fn,
                            recall_cardinality_fn = improved_cardinality_fn,
                            precision_bias_fn = None,
                            precision_cardinality_fn = None,
                            anomaly_ranges = None,
                            prediction_ranges = None,
                            weighted_precision = False):
    has_anomalies = np.any(anomalies > 0)
    has_predictions = np.any(predictions > 0)

    if not has_predictions and not has_anomalies:
        return 1, 1
    elif not has_predictions or not has_anomalies:
        return 0, 0

    if precision_bias_fn is None:
        precision_bias_fn = recall_bias_fn
    if precision_cardinality_fn is None:
        precision_cardinality_fn = recall_cardinality_fn

    if anomaly_ranges is None:
        anomaly_ranges = compute_window_indices(anomalies)
    if prediction_ranges is None:
        prediction_ranges = compute_window_indices(predictions)

    recall = _compute_overlap(predictions, prediction_ranges, anomaly_ranges, alpha, recall_bias_fn,
                              recall_cardinality_fn)
    precision = _compute_overlap(anomalies, anomaly_ranges, prediction_ranges, 0, precision_bias_fn,
                                 precision_cardinality_fn, use_window_weight=weighted_precision)

    return precision, recall

class ano_evaluator:
    def __init__(self, preds, targets = None):
        assert len(preds) == len(targets)

        try:
            preds = np.asarray(preds)
            targets = np.asarray(targets)
        except TypeError:
            preds = np.asarray(preds.cpu())
            targets = np.asarray(targets.cpu())

        self.targets = targets
        self.preds = preds

    def eval_naive_f1(self):
        f1 = metrics.f1_score(self.targets, self.preds, zero_division = 0)
        prec = metrics.precision_score(self.targets, self.preds, zero_division=0)
        recall = metrics.recall_score(self.targets, self.preds, zero_division=0)
        return f1, prec, recall

    def eval_pak_auc(self):
        pak_metrics_list = []
        for k in np.arange(0,110, 10):
            preds_new = copy.deepcopy(self.preds)
            targets_new = copy.deepcopy(self.targets)
            pa_scores = pak(preds_new, targets_new, k)
            pak_metrics_list.append([metrics.f1_score(targets_new, pa_scores, zero_division = 0),
                                     metrics.precision_score(targets_new, pa_scores, zero_division=0),
                                     metrics.recall_score(targets_new, pa_scores, zero_division=0),
                                     ])
        pak_metrics = np.array(pak_metrics_list)
        f1_pak_auc = metrics.auc(np.arange(0,110, 10), pak_metrics[:,0]) / 100.0
        prec_pak_auc = metrics.auc(np.arange(0,110, 10), pak_metrics[:,1]) / 100.0
        recall_pak_auc = metrics.auc(np.arange(0,110, 10), pak_metrics[:,2]) / 100.0

        return f1_pak_auc, prec_pak_auc, recall_pak_auc

    def eval_f1_composite(self):
        true_events = get_events(self.targets)
        prec_pw, rec_ew, f1_comp = get_composite_fscore_raw(self.preds, true_events, self.targets, return_prec_rec=True)
        return f1_comp, prec_pw, rec_ew

    def eval_f1_range(self):
        epsilon = 1e-8
        label_ranges = compute_window_indices(self.targets)
        prec, recall = ts_precision_and_recall(self.targets, self.preds, alpha=0,
                                                anomaly_ranges=label_ranges,
                                                weighted_precision=True)
        f1 = (1 + 1**2) * prec * recall / (1**2 * prec + recall + epsilon)
        return f1, prec, recall

def return_scores(evaluator):
    result_f1, prec, rec = evaluator.eval_naive_f1()
    result_f1, prec, rec = round(result_f1, 5), round(prec, 5),round(rec, 5)

    result_f1_pak, pre_pak, rec_pak = evaluator.eval_pak_auc()
    result_f1_pak, pre_pak, rec_pak = round(result_f1_pak, 5), round(pre_pak, 5),round(rec_pak, 5)

    result_f1_comp, pre_comp, rec_comp = evaluator.eval_f1_composite()
    result_f1_comp, pre_comp, rec_comp = round(result_f1_comp, 5), round(pre_comp, 5),round(rec_comp, 5)

    result_f1_range, pre_range, rec_range = evaluator.eval_f1_range()
    result_f1_range, pre_range, rec_range = round(result_f1_range, 5), round(pre_range, 5),round(rec_range, 5)

    return result_f1, prec, rec, result_f1_pak, pre_pak, rec_pak, result_f1_comp, pre_comp, rec_comp, result_f1_range, pre_range, rec_range

# %%
if torch.is_tensor(y_preds):
    y_preds = y_preds.detach().cpu().numpy()

if torch.is_tensor(y_targets):
    y_targets = y_targets.detach().cpu().numpy()

y_preds = np.array(y_preds)
y_targets = np.array(y_targets)

y_preds = y_preds.astype(int)
y_targets = y_targets.astype(int)

evaluator = ano_evaluator(y_preds, y_targets)

f1, precision, recall, f1_k, precision_k, recall_k, f1_c, precision_c, recall_c, f1_r, precision_r, recall_r = return_scores(evaluator)
print("Point-wise F1:", f1)
print("Point-wise Precision:", precision)
print("Point-wise Recall:", recall)

print("F1-k (PAK):", f1_k)
print("Precision-k:", precision_k)
print("Recall-k:", recall_k)

print("F1-c (Composite):", f1_c)
print("Precision-c:", precision_c)
print("Recall-c:", recall_c)

print("F1-r (Range):", f1_r)
print("Precision-r:", precision_r)
print("Recall-r:", recall_r)
# Out:
# Point-wise F1: 0.49316
# Point-wise Precision: 0.57856
# Point-wise Recall: 0.42973
# F1-k (PAK): 0.64879
# Precision-k: 0.65629
# Recall-k: 0.66499
# F1-c (Composite): 0.73302
# Precision-c: 0.57856
# Recall-c: 1.0
# F1-r (Range): 0.40488
# Precision-r: 0.57856
# Recall-r: 0.3114
